# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
#
# ## Project: **Finding Lane Lines on the Road**
# ***
# In this project, you will use the tools you learned about in the lesson to identify lane lines on the road.  You can develop your pipeline on a series of individual images, and later apply the result to a video stream (really just a series of images). Check out the video clip "raw-lines-example.mp4" (also contained in this repository) to see what the output should look like after using the helper functions below.
#
# Once you have a result that looks roughly like "raw-lines-example.mp4", you'll need to get creative and try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines.  You can see an example of the result you're going for in the video "P1_example.mp4".  Ultimately, you would like to draw just one line for the left side of the lane, and one for the right.
#
# In addition to implementing code, there is a brief writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) that can be used to guide the writing process. Completing both the code in the Ipython notebook and the writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/322/view) for this project.
#
# ---
# Let's have a look at our first image called 'test_images/solidWhiteRight.jpg'.  Run the 2 cells below (hit Shift-Enter or the "play" button above) to display the image.
#
# **Note: If, at any point, you encounter frozen display windows or other confounding issues, you can always start again with a clean slate by going to the "Kernel" menu above and selecting "Restart & Clear Output".**
#
# ---

# %% [markdown]
# **The tools you have are color selection, region of interest selection, grayscaling, Gaussian smoothing, Canny Edge Detection and Hough Tranform line detection.  You  are also free to explore and try other techniques that were not presented in the lesson.  Your goal is piece together a pipeline to detect the line segments in the image, then average/extrapolate them and draw them onto the image for display (as below).  Once you have a working pipeline, try it out on the video stream below.**
#
# ---
#
# <figure>
#  <img src="examples/line-segments-example.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above) after detecting line segments using the helper functions below </p>
#  </figcaption>
# </figure>
#  <p></p>
# <figure>
#  <img src="examples/laneLines_thirdPass.jpg" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your goal is to connect/average/extrapolate line segments to get output like this</p>
#  </figcaption>
# </figure>

# %% [markdown]
# **Run the cell below to import some packages.  If you get an `import error` for a package you've already installed, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt.  Also, see [this forum post](https://carnd-forums.udacity.com/cq/viewquestion.action?spaceKey=CAR&id=29496372&questionTitle=finding-lanes---import-cv2-fails-even-though-python-in-the-terminal-window-has-no-problem-with-import-cv2) for more troubleshooting tips.**

# %% [markdown]
# ## Import Packages

# %%
#importing some useful packages
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import cv2
# %matplotlib inline

# %% [markdown]
# ## Read in an Image

# %%
#reading in an image
image = mpimg.imread('test_images/solidWhiteRight.jpg')

#printing out some stats and plotting
print('This image is:', type(image), 'with dimensions:', image.shape)
plt.imshow(image)  # if you wanted to show a single color channel image called 'gray', for example, call as plt.imshow(gray, cmap='gray')
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (540, 960, 3)

# %% [markdown]
# ## Ideas for Lane Detection Pipeline

# %% [markdown]
# **Some OpenCV functions (beyond those introduced in the lesson) that might be useful for this project are:**
#
# `cv2.inRange()` for color selection
# `cv2.fillPoly()` for regions selection
# `cv2.line()` to draw lines on an image given endpoints
# `cv2.addWeighted()` to coadd / overlay two images
# `cv2.cvtColor()` to grayscale or change color
# `cv2.imwrite()` to output images to file
# `cv2.bitwise_and()` to apply a mask to an image
#
# **Check out the OpenCV documentation to learn about these and discover even more awesome functionality!**

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# Below are some helper functions to help get you started. They should look familiar from the lesson!

# %%
import math

def grayscale(img):
    """Applies the Grayscale transform
    This will return an image with only one color channel
    but NOTE: to see the returned image as grayscale
    (assuming your grayscaled image is called 'gray')
    you should call plt.imshow(gray, cmap='gray')"""
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    # Or use BGR2GRAY if you read an image with cv2.imread()
    # return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def gaussian_blur(img, kernel_size):
    """Applies a Gaussian Noise kernel"""
    return cv2.GaussianBlur(img, (kernel_size, kernel_size), 0)

def region_of_interest(img, vertices):
    """
    Applies an image mask.
    
    Only keeps the region of the image defined by the polygon
    formed from `vertices`. The rest of the image is set to black.
    """
    #defining a blank mask to start with
    mask = np.zeros_like(img)   
    
    #defining a 3 channel or 1 channel color to fill the mask with depending on the input image
    if len(img.shape) > 2:
        channel_count = img.shape[2]  # i.e. 3 or 4 depending on your image
        ignore_mask_color = (255,) * channel_count
    else:
        ignore_mask_color = 255
        
    #filling pixels inside the polygon defined by "vertices" with the fill color    
    cv2.fillPoly(mask, vertices, ignore_mask_color)
    
    #returning the image only where mask pixels are nonzero
    masked_image = cv2.bitwise_and(img, mask)
    return masked_image


def draw_lines(img, lines, color=[255, 0, 0], thickness=2):
    """
    NOTE: this is the function you might want to use as a starting point once you want to 
    average/extrapolate the line segments you detect to map out the full
    extent of the lane (going from the result shown in raw-lines-example.mp4
    to that shown in P1_example.mp4).  
    
    Think about things like separating line segments by their 
    slope ((y2-y1)/(x2-x1)) to decide which segments are part of the left
    line vs. the right line.  Then, you can average the position of each of 
    the lines and extrapolate to the top and bottom of the lane.
    
    This function draws `lines` with `color` and `thickness`.    
    Lines are drawn on the image inplace (mutates the image).
    If you want to make the lines semi-transparent, think about combining
    this function with the weighted_img() function below
    """
    slope_threshold = 0.1
    
    for line in lines:
        for x1,y1,x2,y2 in line:
            if(abs(y2-y1)> slope_threshold*abs(x2-x1)):            
                cv2.line(img, (x1, y1), (x2, y2), color, thickness)

def hough_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    line_img = np.zeros((img.shape[0], img.shape[1], 3), dtype=np.uint8)
    draw_lines(line_img, lines)
    return line_img

def hough_lines_return_lines(img, rho, theta, threshold, min_line_len, max_line_gap):
    """
    `img` should be the output of a Canny transform.
        
    Returns an image with hough lines drawn.
    """
    lines = cv2.HoughLinesP(img, rho, theta, threshold, np.array([]), minLineLength=min_line_len, maxLineGap=max_line_gap)
    return lines



# Python 3 has support for cool math symbols.

def weighted_img(img, initial_img, α=0.8, β=1., λ=0.):
    """
    `img` is the output of the hough_lines(), An image with lines drawn on it.
    Should be a blank image (all black) with lines drawn on it.
    
    `initial_img` should be the image before any processing.
    
    The result image is computed as follows:
    
    initial_img * α + img * β + λ
    NOTE: initial_img and img must be the same shape!
    """
    return cv2.addWeighted(initial_img, α, img, β, λ)

# %% [markdown]
# ## Test Images
#
# Build your pipeline to work on the images in the directory "test_images"
# **You should make sure your pipeline works well on these images before you try the videos.**

# %%
import os
os.listdir("test_images/")
os.listdir("test_images/")[1]
# Out:
# 'solidWhiteRight.jpg'

# %% [markdown]
# ## Build a Lane Finding Pipeline

# %% [markdown]
# Build the pipeline and run your solution on all test_images. Make copies into the `test_images_output` directory, and you can use the images in your writeup report.
#
# Try tuning the various parameters, especially the low and high Canny thresholds as well as the Hough lines parameters.

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images directory.

#Load
#Grayscale
#canny edge detection
#mask
#hough_transform

#Parameters
kernel_size = 1 # Kernel size for Gaussian Bluring
canny_edge_det_low = 50 # Low Threshold for canny edge detection
canny_edge_det_high = 100 # High Threshold for canny edge detection

rho = 1 # distance resolution in pixels of the Hough grid
theta = np.pi/180 # angular resolution in radians of the Hough grid
threshold = 5     # minimum number of votes (intersections in Hough grid cell)
min_line_length = 20 #minimum number of pixels making up a line
max_line_gap = 3    # maximum gap in pixels between connectable line segments

name = os.listdir("test_images/")[1]

#Load Image
orig_image = mpimg.imread("test_images/" + name)

imshape = orig_image.shape;

#plt.imshow(image)

#Transform the image to a grayscale image
image = grayscale(orig_image)


#Use the canny edge detection algorithm
#Blure the image
gaussian_blur(image,kernel_size)
edges = canny(image,canny_edge_det_low,canny_edge_det_high)

#plt.imshow(edges, cmap='gray')
#Define Mask
horizon_level = 0.6

#mask_vertices = np.array([[(0.4*imshape[1],0.55*imshape[0]),(0.6*imshape[1],0.55*imshape[0]), (0*imshape[1], imshape[0]), (1.0*imshape[1],imshape[0])]], dtype=np.int32)
mask_vertices = np.array([[(0*imshape[1],1*imshape[0]),(1.0*imshape[1],1*imshape[0]), (0.6*imshape[1], horizon_level*imshape[0]),(0.4*imshape[1], horizon_level*imshape[0])]], dtype=np.int32)

#full = np.ones((imshape[0], imshape[1], 1), dtype=np.uint8)

masked_edges = region_of_interest(edges,mask_vertices)

#plt.imshow(masked_edges, cmap='gray')
#h_l_image = hough_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)
found_lines = hough_lines_return_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)

#plt.imshow(h_l_image)


#Sort lines into left and right lines (Remove also horizontal lines)
rho_vals = np.zeros(found_lines.shape[0])
phi_vals = np.zeros(found_lines.shape[0])

lines_added = 0

for line in found_lines:
    for x_1,y_1,x_2,y_2 in line:
        div = (x_2-x_1)**2+(y_2-y_1)**2
        scal = (x_1*(x_1-x_2)+y_1*(y_1-y_2))/div
        point_close_to_origin = [x_1+(x_2-x_1)*scal,y_1+(y_2-y_1)*scal]
        rho = np.linalg.norm(point_close_to_origin,2)
        phi = math.atan2(point_close_to_origin[1],point_close_to_origin[0])
        #Remove all lines which are close to horizontal lines
        
        if(abs(phi-np.pi/2)>-0.5):
            rho_vals[lines_added] = rho
            phi_vals[lines_added] = phi
            lines_added = lines_added + 1

rho_vals = rho_vals[0:lines_added-1]
phi_vals = phi_vals[0:lines_added-1]

print(phi_vals)

#Use 2 center algorithm to distinguish between left and right lines

#Standardize Input
mean_rho = np.mean(rho_vals)
mean_phi = np.mean(phi_vals)
std_rho = np.std(rho_vals)
std_phi = np.std(phi_vals)

rho_vals = (rho_vals - mean_rho)/std_rho
phi_vals = (phi_vals - mean_phi)/std_phi

#Choose to starting centers
#start_one_index = np.argmin(rho_vals)
#start_two_index = np.argmax(rho_vals)

#center_one =  np.array([rho_vals[start_one_index],phi_vals[start_one_index]])
#center_two = np.array([rho_vals[start_two_index],phi_vals[start_two_index]])

center_one =  np.array([-1,0],dtype = np.float64)
center_two =  np.array([1,0],dtype = np.float64)

rho_phi_combined = np.zeros((rho_vals.shape[0],2))

rho_phi_combined[:,0] = rho_vals
rho_phi_combined[:,1] = phi_vals

out_lier_dist = 1.0

for i in range(1,5):
    #Compute distance from center to all points
    distance_one = np.linalg.norm(rho_phi_combined-center_one,axis = 1)
    distance_two = np.linalg.norm(rho_phi_combined-center_two,axis = 1)
    
    one_closer = (distance_one < distance_two)
    
    no_out_lier_for_one = (distance_one < out_lier_dist)
    no_out_lier_for_two = (distance_two < out_lier_dist)

    #Define new centers
    
    print(np.mean(rho_vals[one_closer]))
    
    center_one[0] = np.mean(rho_vals[one_closer & no_out_lier_for_one])
    center_one[1] = np.mean(phi_vals[one_closer & no_out_lier_for_one])
    
    center_two[0] = np.mean(rho_vals[~one_closer  & no_out_lier_for_two])
    center_two[1] = np.mean(phi_vals[~one_closer  & no_out_lier_for_two])
    
    
plt.scatter(rho_vals,phi_vals, c = 'black')
plt.scatter(center_one[0],center_one[1], c = 'red')
plt.scatter(center_two[0],center_two[1], c = 'blue')
    
#Remove standardization form the centers
center_one[0] = center_one[0]*std_rho + mean_rho
center_one[1] = center_one[1]*std_phi + mean_phi
    
center_two[0] = center_two[0]*std_rho + mean_rho
center_two[1] = center_two[1]*std_phi + mean_phi
    

#Tranform centers to lines
y_bot = imshape[0]
y_hor = horizon_level*imshape[0]

x_bot_one = (center_one[0]-np.sin(center_one[1])*y_bot)/np.cos(center_one[1])
x_hor_one = (center_one[0]-np.sin(center_one[1])*y_hor)/np.cos(center_one[1])

x_bot_two = (center_two[0]-np.sin(center_two[1])*y_bot)/np.cos(center_two[1])
x_hor_two = (center_two[0]-np.sin(center_two[1])*y_hor)/np.cos(center_two[1])

line_one = np.array([x_bot_one,y_bot,x_hor_one,y_hor], dtype = np.int32)
line_two = np.array([x_bot_two,y_bot,x_hor_two,y_hor], dtype = np.int32)

line_img = np.zeros((imshape[0], imshape[1], 3), dtype=np.uint8)

cv2.line(line_img, (line_one[0], line_one[1]), (line_one[2], line_one[3]), [255, 0, 0], 10)
cv2.line(line_img, (line_two[0], line_two[1]), (line_two[2], line_two[3]), [255, 0, 0], 10)

print(line_one)
print(line_two)

both_mixed = weighted_img(line_img,orig_image)

plt.imshow(both_mixed)

#Refine Lines with poly fit
# Out:
# [ 2.12939564 -0.99276348 -0.99352037 -0.94200004  0.92092588  0.97779376
#  -0.99227211  0.91290772  0.92729522  1.57079633  0.          1.57079633
#   0.92729522  2.12510382]
# -0.99770555128
# -0.99770555128
# -0.996291570553
# -0.996291570553
# [549 540 333 324]
# [ 69 540 510 324]

# %%
# TODO: Build your pipeline that will draw lane lines on the test_images
# then save them to the test_images directory.

#Load
#Grayscale
#canny edge detection
#mask
#hough_transform

#Parameters
kernel_size = 1 # Kernel size for Gaussian Bluring
canny_edge_det_low = 50 # Low Threshold for canny edge detection
canny_edge_det_high = 100 # High Threshold for canny edge detection

rho = 1 # distance resolution in pixels of the Hough grid
theta = np.pi/180 # angular resolution in radians of the Hough grid
threshold = 5     # minimum number of votes (intersections in Hough grid cell)
min_line_length = 20 #minimum number of pixels making up a line
max_line_gap = 3    # maximum gap in pixels between connectable line segments

name = os.listdir("test_images/")[5]

#Load Image
orig_image = mpimg.imread("test_images/" + name)

imshape = orig_image.shape;

#plt.imshow(image)

#Transform the image to a grayscale image
image = grayscale(orig_image)


#Use the canny edge detection algorithm
#Blure the image
gaussian_blur(image,kernel_size)
edges = canny(image,canny_edge_det_low,canny_edge_det_high)

#plt.imshow(edges, cmap='gray')
#Define Mask
horizon_level = 0.6

#mask_vertices = np.array([[(0.4*imshape[1],0.55*imshape[0]),(0.6*imshape[1],0.55*imshape[0]), (0*imshape[1], imshape[0]), (1.0*imshape[1],imshape[0])]], dtype=np.int32)
mask_vertices = np.array([[(0*imshape[1],1*imshape[0]),(1.0*imshape[1],1*imshape[0]), (0.6*imshape[1], horizon_level*imshape[0]),(0.4*imshape[1], horizon_level*imshape[0])]], dtype=np.int32)

#full = np.ones((imshape[0], imshape[1], 1), dtype=np.uint8)

masked_edges = region_of_interest(edges,mask_vertices)

#plt.imshow(masked_edges, cmap='gray')
h_l_image = hough_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)
#found_lines = hough_lines_return_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)



#Split in the middle of the window
xx, yy = np.meshgrid(np.arange(0,imshape[1],1) , np.arange(0,imshape[0],1))

points_left = h_l_image[:,:,0] & (xx < 0.5*imshape[1])
points_right = h_l_image[:,:,0] & (xx > 0.5*imshape[1])

xx_left_points = xx[points_left==1]
yy_left_points = yy[points_left==1]

xx_right_points = xx[points_right==1]
yy_right_points = yy[points_right==1]

#Define Ransac Algorithm
number_ransac_tries = 25
number_left_points = len(xx_left_points)
number_right_points = len(xx_right_points)

best_val_found_left = np.inf
best_line_params_left = np.array([0,0])

best_val_found_right = np.inf
best_line_params_right = np.array([0,0])

for ran_try in range(0,number_ransac_tries):
    #Pick 2 random points
    index_1_left = np.random.randint(0,number_left_points)
    index_2_left = np.random.randint(0,number_left_points)
    index_1_right = np.random.randint(0,number_right_points)
    index_2_right = np.random.randint(0,number_right_points)
    
    #Fit a line to these points
    x_vals_to_fit_left = np.array([xx_left_points[index_1_left],xx_left_points[index_2_left]])
    y_vals_to_fit_left = np.array([yy_left_points[index_1_left],yy_left_points[index_2_left]])
    line_params_left = np.polyfit(x_vals_to_fit_left,y_vals_to_fit_left,1)
    
    x_vals_to_fit_right = np.array([xx_right_points[index_1_right],xx_right_points[index_2_right]])
    y_vals_to_fit_right = np.array([yy_right_points[index_1_right],yy_right_points[index_2_right]])
    line_params_right = np.polyfit(x_vals_to_fit_right,y_vals_to_fit_right,1)
        
    m_left = line_params_left[0]
    b_left = line_params_left[1]
    
    m_right = line_params_right[0]
    b_right = line_params_right[1]
    
    #Evaluate the value of this line
    val_of_this_line_left = sum(min(1,abs(1/m_left))*abs(m_left*xx_left_points - yy_left_points + b_left))
    val_of_this_line_right = sum(min(1,abs(1/m_right))*abs(m_right*xx_right_points - yy_right_points + b_right))

    #Compare to best line
    if(val_of_this_line_left < best_val_found_left):
        best_val_found_left = val_of_this_line_left
        best_line_params_left = line_params_left
        
    if(val_of_this_line_right < best_val_found_right):
        best_val_found_right = val_of_this_line_right
        best_line_params_right = line_params_right

#Draw line
new_lines = np.ndarray(shape = (2,1,4),dtype = np.int32)

new_lines[0,0,0] = (imshape[0]-best_line_params_left[1])/best_line_params_left[0]
new_lines[0,0,1] = imshape[0]
new_lines[0,0,2] = (0.6*imshape[0]-best_line_params_left[1])/best_line_params_left[0]
new_lines[0,0,3] = 0.6*imshape[0]

new_lines[1,0,0] = (imshape[0]-best_line_params_right[1])/best_line_params_right[0]
new_lines[1,0,1] = imshape[0]
new_lines[1,0,2] = (0.6*imshape[0]-best_line_params_right[1])/best_line_params_right[0]
new_lines[1,0,3] = 0.6*imshape[0]

draw_lines(h_l_image,new_lines,color=[0,255,0])
        
only_line = np.zeros((image.shape[0], image.shape[1], 3), dtype=np.uint8)
only_line[:,:,0] = h_l_image[:,:,1]

both_mixed = weighted_img(only_line,orig_image)

#Refine lines using Polyfit



plt.imshow(both_mixed)

# %% [markdown]
# ## Test on Videos
#
# You know what's cooler than drawing lanes over images? Drawing lanes over video!
#
# We can test our solution on two provided videos:
#
# `solidWhiteRight.mp4`
#
# `solidYellowLeft.mp4`
#
# **Note: if you get an `import error` when you run the next cell, try changing your kernel (select the Kernel menu above --> Change Kernel).  Still have problems?  Try relaunching Jupyter Notebook from the terminal prompt. Also, check out [this forum post](https://carnd-forums.udacity.com/questions/22677062/answers/22677109) for more troubleshooting tips.**
#
# **If you get an error that looks like this:**
# ```
# NeedDownloadError: Need ffmpeg exe.
# You can download it by calling:
# imageio.plugins.ffmpeg.download()
# ```
# **Follow the instructions in the error message and check out [this forum post](https://carnd-forums.udacity.com/display/CAR/questions/26218840/import-videofileclip-error) for more troubleshooting tips across operating systems.**

# %%
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML

# %%
def process_image(image):
    # NOTE: The output you return should be a color image (3 channel) for processing video below
    # TODO: put your pipeline here,
    # you should return the final output (image where lines are drawn on lanes)

    #Parameters
    kernel_size = 1 # Kernel size for Gaussian Bluring
    canny_edge_det_low = 50 # Low Threshold for canny edge detection
    canny_edge_det_high = 100 # High Threshold for canny edge detection

    rho = 1 # distance resolution in pixels of the Hough grid
    theta = np.pi/180 # angular resolution in radians of the Hough grid
    threshold = 5     # minimum number of votes (intersections in Hough grid cell)
    min_line_length = 20 #minimum number of pixels making up a line
    max_line_gap = 3    # maximum gap in pixels between connectable line segments

    name = os.listdir("test_images/")[5]

    #Load Image
    orig_image = mpimg.imread("test_images/" + name)

    imshape = orig_image.shape;

    #plt.imshow(image)

    #Transform the image to a grayscale image
    image = grayscale(orig_image)


    #Use the canny edge detection algorithm
    #Blure the image
    gaussian_blur(image,kernel_size)
    edges = canny(image,canny_edge_det_low,canny_edge_det_high)

    #plt.imshow(edges, cmap='gray')
    #Define Mask
    horizon_level = 0.6

    #mask_vertices = np.array([[(0.4*imshape[1],0.55*imshape[0]),(0.6*imshape[1],0.55*imshape[0]), (0*imshape[1], imshape[0]), (1.0*imshape[1],imshape[0])]], dtype=np.int32)
    mask_vertices = np.array([[(0*imshape[1],1*imshape[0]),(1.0*imshape[1],1*imshape[0]), (0.6*imshape[1], horizon_level*imshape[0]),(0.4*imshape[1], horizon_level*imshape[0])]], dtype=np.int32)

    #full = np.ones((imshape[0], imshape[1], 1), dtype=np.uint8)

    masked_edges = region_of_interest(edges,mask_vertices)

    #plt.imshow(masked_edges, cmap='gray')
    h_l_image = hough_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)
    #found_lines = hough_lines_return_lines(masked_edges,rho,theta,threshold,min_line_length,max_line_gap)



    #Split in the middle of the window
    xx, yy = np.meshgrid(np.arange(0,imshape[1],1) , np.arange(0,imshape[0],1))

    points_left = h_l_image[:,:,0] & (xx < 0.5*imshape[1])
    points_right = h_l_image[:,:,0] & (xx > 0.5*imshape[1])

    xx_left_points = xx[points_left==1]
    yy_left_points = yy[points_left==1]

    xx_right_points = xx[points_right==1]
    yy_right_points = yy[points_right==1]

    #Define Ransac Algorithm
    number_ransac_tries = 25
    number_left_points = len(xx_left_points)
    number_right_points = len(xx_right_points)

    best_val_found_left = np.inf
    best_line_params_left = np.array([0,0])

    best_val_found_right = np.inf
    best_line_params_right = np.array([0,0])

    for ran_try in range(0,number_ransac_tries):
        #Pick 2 random points
        index_1_left = np.random.randint(0,number_left_points)
        index_2_left = np.random.randint(0,number_left_points)
        index_1_right = np.random.randint(0,number_right_points)
        index_2_right = np.random.randint(0,number_right_points)

        #Fit a line to these points
        x_vals_to_fit_left = np.array([xx_left_points[index_1_left],xx_left_points[index_2_left]])
        y_vals_to_fit_left = np.array([yy_left_points[index_1_left],yy_left_points[index_2_left]])
        line_params_left = np.polyfit(x_vals_to_fit_left,y_vals_to_fit_left,1)

        x_vals_to_fit_right = np.array([xx_right_points[index_1_right],xx_right_points[index_2_right]])
        y_vals_to_fit_right = np.array([yy_right_points[index_1_right],yy_right_points[index_2_right]])
        line_params_right = np.polyfit(x_vals_to_fit_right,y_vals_to_fit_right,1)

        m_left = line_params_left[0]
        b_left = line_params_left[1]

        m_right = line_params_right[0]
        b_right = line_params_right[1]

        #Evaluate the value of this line
        val_of_this_line_left = sum(min(1,abs(1/m_left))*abs(m_left*xx_left_points - yy_left_points + b_left))
        val_of_this_line_right = sum(min(1,abs(1/m_right))*abs(m_right*xx_right_points - yy_right_points + b_right))

        #Compare to best line
        if(val_of_this_line_left < best_val_found_left):
            best_val_found_left = val_of_this_line_left
            best_line_params_left = line_params_left

        if(val_of_this_line_right < best_val_found_right):
            best_val_found_right = val_of_this_line_right
            best_line_params_right = line_params_right

    #Draw line
    new_lines = np.ndarray(shape = (2,1,4),dtype = np.int32)

    new_lines[0,0,0] = (imshape[0]-best_line_params_left[1])/best_line_params_left[0]
    new_lines[0,0,1] = imshape[0]
    new_lines[0,0,2] = (0.6*imshape[0]-best_line_params_left[1])/best_line_params_left[0]
    new_lines[0,0,3] = 0.6*imshape[0]

    new_lines[1,0,0] = (imshape[0]-best_line_params_right[1])/best_line_params_right[0]
    new_lines[1,0,1] = imshape[0]
    new_lines[1,0,2] = (0.6*imshape[0]-best_line_params_right[1])/best_line_params_right[0]
    new_lines[1,0,3] = 0.6*imshape[0]

    draw_lines(h_l_image,new_lines,color=[0,255,0])

    only_line = np.zeros((image.shape[0], image.shape[1], 3), dtype=np.uint8)
    only_line[:,:,0] = h_l_image[:,:,1]

    both_mixed = weighted_img(only_line,orig_image)

    return both_mixed

# %% [markdown]
# Let's try the one with the solid white lane on the right first ...

# %%
white_output = 'test_videos_output/solidWhiteRight.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4").subclip(0,5)
clip1 = VideoFileClip("test_videos/solidWhiteRight.mp4")
white_clip = clip1.fl_image(process_image) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# MoviePy: building video file test_videos_output/solidWhiteRight.mp4
# ----------------------------------------
#
# Writing video into test_videos_output/solidWhiteRight.mp4
# |----------| 0/213   0% [elapsed: 00:00 left: ?, ? iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |----------| 10/213   4% [elapsed: 00:00 left: 00:10, 18.58 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |----------| 19/213   8% [elapsed: 00:01 left: 00:10, 18.24 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |#---------| 29/213  13% [elapsed: 00:01 left: 00:10, 18.19 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |#---------| 39/213  18% [elapsed: 00:02 left: 00:09, 18.22 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |##--------| 49/213  23% [elapsed: 00:02 left: 00:09, 18.15 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |##--------| 58/213  27% [elapsed: 00:03 left: 00:08, 18.09 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |###-------| 67/213  31% [elapsed: 00:03 left: 00:08, 18.03 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |###-------| 74/213  34% [elapsed: 00:04 left: 00:07, 17.43 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |###-------| 83/213  38% [elapsed: 00:04 left: 00:07, 17.42 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |####------| 102/213  47% [elapsed: 00:05 left: 00:06, 17.53 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 112/213  52% [elapsed: 00:06 left: 00:05, 17.57 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:98: RuntimeWarning: divide by zero encountered in double_scalars
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 122/213  57% [elapsed: 00:06 left: 00:05, 17.63 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |######----| 132/213  61% [elapsed: 00:07 left: 00:04, 17.69 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |######----| 141/213  66% [elapsed: 00:07 left: 00:04, 17.71 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# |#######---| 150/213  70% [elapsed: 00:08 left: 00:03, 17.72 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |#######---| 160/213  75% [elapsed: 00:09 left: 00:02, 17.73 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |#######---| 170/213  79% [elapsed: 00:09 left: 00:02, 17.76 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |########--| 179/213  84% [elapsed: 00:10 left: 00:01, 17.77 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |########--| 189/213  88% [elapsed: 00:10 left: 00:01, 17.80 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# |#########-| 199/213  93% [elapsed: 00:11 left: 00:00, 17.80 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:89: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:85: RankWarning: Polyfit may be poorly conditioned
# Done writing video in test_videos_output/solidWhiteRight.mp4 !
# Your video is ready !
# Wall time: 12.1 s

# %% [markdown]
# Play the video inline, or if you prefer find the video in your filesystem (should be in the same directory) and play it in your video player of choice.

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(white_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidWhiteRight.mp4">
# </video>

# %% [markdown]
# ## Improve the draw_lines() function
#
# **At this point, if you were successful with making the pipeline and tuning parameters, you probably have the Hough line segments drawn onto the road, but what about identifying the full extent of the lane and marking it clearly as in the example video (P1_example.mp4)?  Think about defining a line to run the full length of the visible lane based on the line segments you identified with the Hough Transform. As mentioned previously, try to average and/or extrapolate the line segments you've detected to map out the full extent of the lane lines. You can see an example of the result you're going for in the video "P1_example.mp4".**
#
# **Go back and modify your draw_lines function accordingly and try re-running your pipeline. The new output should draw a single, solid line over the left lane line and a single, solid line over the right lane line. The lines should start from the bottom of the image and extend out to the top of the region of interest.**

# %% [markdown]
# Now for the one with the solid yellow lane on the left. This one's more tricky!

# %%
yellow_output = 'test_videos_output/solidYellowLeft.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4').subclip(0,5)
clip2 = VideoFileClip('test_videos/solidYellowLeft.mp4')
yellow_clip = clip2.fl_image(process_image)
# %time yellow_clip.write_videofile(yellow_output, audio=False)
# Out:
# MoviePy: building video file test_videos_output/solidYellowLeft.mp4
# ----------------------------------------
#
# Writing video into test_videos_output/solidYellowLeft.mp4
# |----------| 0/654   0% [elapsed: 00:00 left: ?, ? iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |----------| 10/654   1% [elapsed: 00:00 left: 00:33, 19.23 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |----------| 20/654   3% [elapsed: 00:01 left: 00:33, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |----------| 30/654   4% [elapsed: 00:01 left: 00:32, 19.03 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |----------| 40/654   6% [elapsed: 00:02 left: 00:32, 18.96 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |----------| 50/654   7% [elapsed: 00:02 left: 00:31, 18.99 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |----------| 60/654   9% [elapsed: 00:03 left: 00:31, 18.97 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#---------| 70/654  10% [elapsed: 00:03 left: 00:30, 18.95 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#---------| 80/654  12% [elapsed: 00:04 left: 00:30, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#---------| 90/654  13% [elapsed: 00:04 left: 00:29, 18.96 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#---------| 100/654  15% [elapsed: 00:05 left: 00:29, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#---------| 120/654  18% [elapsed: 00:06 left: 00:28, 18.89 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#---------| 130/654  19% [elapsed: 00:06 left: 00:27, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |##--------| 140/654  21% [elapsed: 00:07 left: 00:27, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |##--------| 150/654  22% [elapsed: 00:07 left: 00:26, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |##--------| 160/654  24% [elapsed: 00:08 left: 00:26, 18.95 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |##--------| 170/654  25% [elapsed: 00:08 left: 00:25, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |##--------| 180/654  27% [elapsed: 00:09 left: 00:25, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |##--------| 190/654  29% [elapsed: 00:10 left: 00:24, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |###-------| 200/654  30% [elapsed: 00:10 left: 00:23, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |###-------| 210/654  32% [elapsed: 00:11 left: 00:23, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |###-------| 220/654  33% [elapsed: 00:11 left: 00:22, 18.95 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |###-------| 230/654  35% [elapsed: 00:12 left: 00:22, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |###-------| 240/654  36% [elapsed: 00:12 left: 00:21, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |###-------| 250/654  38% [elapsed: 00:13 left: 00:21, 18.95 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |###-------| 260/654  39% [elapsed: 00:13 left: 00:20, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |####------| 270/654  41% [elapsed: 00:14 left: 00:20, 18.96 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |####------| 280/654  42% [elapsed: 00:14 left: 00:19, 18.96 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |####------| 290/654  44% [elapsed: 00:15 left: 00:19, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |####------| 300/654  45% [elapsed: 00:15 left: 00:18, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |####------| 320/654  48% [elapsed: 00:16 left: 00:17, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 330/654  50% [elapsed: 00:17 left: 00:17, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 340/654  51% [elapsed: 00:17 left: 00:16, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 350/654  53% [elapsed: 00:18 left: 00:16, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 360/654  55% [elapsed: 00:19 left: 00:15, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 370/654  56% [elapsed: 00:19 left: 00:15, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 380/654  58% [elapsed: 00:20 left: 00:14, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#####-----| 390/654  59% [elapsed: 00:20 left: 00:13, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |######----| 400/654  61% [elapsed: 00:21 left: 00:13, 18.95 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |######----| 410/654  62% [elapsed: 00:21 left: 00:12, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |######----| 420/654  64% [elapsed: 00:22 left: 00:12, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |######----| 430/654  65% [elapsed: 00:22 left: 00:11, 18.94 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |######----| 440/654  67% [elapsed: 00:23 left: 00:11, 18.93 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#######---| 460/654  70% [elapsed: 00:24 left: 00:10, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#######---| 470/654  71% [elapsed: 00:24 left: 00:09, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#######---| 480/654  73% [elapsed: 00:25 left: 00:09, 18.90 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#######---| 490/654  74% [elapsed: 00:25 left: 00:08, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:88: RuntimeWarning: divide by zero encountered in double_scalars
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#######---| 500/654  76% [elapsed: 00:26 left: 00:08, 18.90 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#######---| 510/654  77% [elapsed: 00:26 left: 00:07, 18.90 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#######---| 520/654  79% [elapsed: 00:27 left: 00:07, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |########--| 530/654  81% [elapsed: 00:28 left: 00:06, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |########--| 540/654  82% [elapsed: 00:28 left: 00:06, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |########--| 550/654  84% [elapsed: 00:29 left: 00:05, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |########--| 560/654  85% [elapsed: 00:29 left: 00:04, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |########--| 570/654  87% [elapsed: 00:30 left: 00:04, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#########-| 590/654  90% [elapsed: 00:31 left: 00:03, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#########-| 600/654  91% [elapsed: 00:31 left: 00:02, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#########-| 610/654  93% [elapsed: 00:32 left: 00:02, 18.92 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#########-| 620/654  94% [elapsed: 00:32 left: 00:01, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# |#########-| 630/654  96% [elapsed: 00:33 left: 00:01, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# |#########-| 640/654  97% [elapsed: 00:33 left: 00:00, 18.91 iters/sec]
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:79: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# B:\Anaconda\envs\sdcnd35\lib\site-packages\ipykernel_launcher.py:75: RankWarning: Polyfit may be poorly conditioned
# Done writing video in test_videos_output/solidYellowLeft.mp4 !
# Your video is ready !
# Wall time: 34.8 s

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(yellow_output))
# Out:
# <video width="960" height="540" controls>
#   <source src="test_videos_output/solidYellowLeft.mp4">
# </video>

# %% [markdown]
# ## Writeup and Submission
#
# If you're satisfied with your video outputs, it's time to make the report writeup in a pdf or markdown file. Once you have this Ipython notebook ready along with the writeup, it's time to submit for review! Here is a [link](https://github.com/udacity/CarND-LaneLines-P1/blob/master/writeup_template.md) to the writeup template file.

# %% [markdown]
# ## Optional Challenge
#
# Try your lane finding pipeline on the video below.  Does it still work?  Can you figure out a way to make it more robust?  If you're up for the challenge, modify your pipeline so it works with this video and submit it along with the rest of your project!

# %%
challenge_output = 'test_videos_output/challenge.mp4'
## To speed up the testing process you may want to try your pipeline on a shorter subclip of the video
## To do so add .subclip(start_second,end_second) to the end of the line below
## Where start_second and end_second are integer values representing the start and end of the subclip
## You may also uncomment the following line for a subclip of the first 5 seconds
##clip3 = VideoFileClip('test_videos/challenge.mp4').subclip(0,5)
clip3 = VideoFileClip('test_videos/challenge.mp4')
challenge_clip = clip3.fl_image(process_image)
# %time challenge_clip.write_videofile(challenge_output, audio=False)

# %%
HTML("""
<video width="960" height="540" controls>
  <source src="{0}">
</video>
""".format(challenge_output))
